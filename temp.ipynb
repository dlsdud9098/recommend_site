# %%
import pickle
import pandas as pd

with open('data/naver_novel_data.data', 'rb') as f:
    a = pickle.load(f)

df = pd.DataFrame(a)
df = df[df.notnull()]
df
# Out:
#                                                      url  \
# 0      https://series.naver.com/novel/detail.series?p...
# 1      https://series.naver.com/novel/detail.series?p...
# 2      https://series.naver.com/novel/detail.series?p...
# 3      https://series.naver.com/novel/detail.series?p...
# 4      https://series.naver.com/novel/detail.series?p...
# ...                                                  ...
# 34124  https://series.naver.com/novel/detail.series?p...
# 34125  https://series.naver.com/novel/detail.series?p...
# 34126  https://series.naver.com/novel/detail.series?p...
# 34127  https://series.naver.com/novel/detail.series?p...
# 34128  https://series.naver.com/novel/detail.series?p...
#
#                                                      img  \
# 0      https://comicthumb-phinf.pstatic.net/20241022_...
# 1      https://comicthumb-phinf.pstatic.net/20250310_...
# 2      https://comicthumb-phinf.pstatic.net/20250527_...
# ...
