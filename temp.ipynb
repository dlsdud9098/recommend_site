# %%
from bs4 import BeautifulSoup
with open('asdf.txt', 'r', encoding='utf-8') as f:
    a = f.read()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 4
#       2 with open('asdf.txt', 'r', encoding='utf-8') as f:
#       3     a = f.read()
# ----> 4 a.select_one('a')
#
# AttributeError: 'str' object has no attribute 'select_one'

# %%
import requests
from bs4 import BeautifulSoup

rq = requests.get('https://series.naver.com/novel/detail.series?productNo=12481255')
soup = BeautifulSoup(rq.text, 'html.parser')

img = soup.select_one('#container > div.aside.NE\=a\:nvi > span > img')
            
if img is None:
    print('이미지 없음')
    
    img = soup.select_one('#container > div > a > img').get('src')
else:
    img = img.get('src')

title = soup.select_one('#content > div.end_head > h2').get_text()
rating = soup.select_one('#content > div.end_head > div.score_area > em').get_text()
genre = soup.select_one('#content > ul.end_info.NE\=a\:nvi > li > ul > li:nth-child(2) > span > a').get_text()
serial = soup.select_one('#content > ul.end_info.NE\=a\:nvi > li > ul > li.ing > span').get_text()
publisher = soup.select_one('#content > ul.end_info.NE\=a\:nvi > li > ul > li:nth-child(4) > a').get_text()
summary = soup.select_one('#content > div.end_dsc > div').get_text()
page_count = soup.select_one('#content > h5 > strong').get_text()
page_unit = soup.select_one('#content > h5').get_text().strip()[-1]

novel_data = {
    'img': img,
    'title': title,
    'rating': rating,
    'genre': genre,
    'serial': serial,
    'publisher': publisher,
    'summary': summary,
    'page_count': page_count,
    'page_unit': page_unit
}

novel_data
# Out:
# {'img': 'https://comicthumb-phinf.pstatic.net/20250414_196/pocket_1744612873353vO7bO_JPEG/%BC%B6%C0%AF_%B0%F8%C0%E5%C0%C7_%C3%B5%C0%E7_%BB%F3%BC%D3%C0%DA_%C5%B8%C0%CC%C6%B2_%C3%D6%C1%BE.jpg?type=m260',
#  'title': '섬유 공장의 천재 상속자',
#  'rating': '9.5',
#  'genre': '현판',
#  'serial': '연재중',
#  'publisher': '문피아',
#  'summary': '【품질적합도=98.5%】\r..\n\t\t\t\t\t\n더보기\n',
#  'page_count': '163',
#  'page_unit': '화'}

# %%
import pandas as pd

df = pd.read_csv('data/naver_novel_data.csv')
print(df.shape)
df[df['url'].notnull()]
# Out:
# (125, 14)
#                                                    url  \
# 0    https://series.naver.com/novel/detail.series?p...
# 2    https://series.naver.com/novel/detail.series?p...
# 3    https://series.naver.com/novel/detail.series?p...
# 4    https://series.naver.com/novel/detail.series?p...
# 5    https://series.naver.com/novel/detail.series?p...
# ..                                                 ...
# 120  https://series.naver.com/novel/detail.series?p...
# 121  https://series.naver.com/novel/detail.series?p...
# 122  https://series.naver.com/novel/detail.series?p...
# 123  https://series.naver.com/novel/detail.series?p...
# 124  https://series.naver.com/novel/detail.series?p...
#
#                                                    img  \
# 0    https://comicthumb-phinf.pstatic.net/20240926_...
# 2    https://comicthumb-phinf.pstatic.net/20250526_...
# 3    https://comicthumb-phinf.pstatic.net/20250106_...
# 4    https://comicthumb-phinf.pstatic.net/20241121_...
# 5    https://comicthumb-phinf.pstatic.net/20241223_...
# ..                                                 ...
# 120  https://comicthumb-phinf.pstatic.net/20250408_...
# 121  https://comicthumb-phinf.pstatic.net/20250409_...
# 122  https://comicthumb-phinf.pstatic.net/20250409_...
# 123  https://comicthumb-phinf.pstatic.net/20250421_...
# 124  https://comicthumb-phinf.pstatic.net/20250424_...
#
#                                 title  rating genre serial publisher  \
# 0                        유랑기사와 움직이는 성     9.7   판타지    연재중       문피아
# 2                  SSS급 마수들이 날 너무 좋아함     7.8   판타지    연재중    알에스미디어
# 3                    은퇴 후 세차장 사장이 됐다.     9.2    현판    연재중       문피아
# 4                      무림에서 카페로 힐링합니다     9.5    무협    연재중       문피아
# 5                          전쟁을 딛고 재벌로     9.5    현판    연재중       문피아
# ..                                ...     ...   ...    ...       ...
# 120         조선귀농실록-조선에 떨어진 삼대 독자 [독점]     7.8   판타지    연재중      KW북스
# 121  망돌 친구 몸에 빙의해 데뷔합니다 [시즌1-2][미니노블]     9.2    현판    연재중   에이시스미디어
# 122                   제천대성이 돌아왔다 [독점]     8.7    무협    연재중       엔리즈
# 123                   포식으로 최강 헌터 [독점]     7.9    현판    연재중     JC미디어
# 124                스트리트 오브 초한지 [무료연재]     9.1    현판    연재중      에필로그
#
#                                                summary  page_count page_unit  \
# 0    [2024 지상최대 웹소설 공모전 수상작]\n\n가장 두려운 기사에게는 가장 두려운...       297.0         화
# 2         길 잃은 새를 도와줬더니 능력을 각성했다.\n유능한 마수들이 날 너무 좋아한다!       177.0         화
# 3          딱 한 번 실수가 은퇴로 이어졌다.\n\n앞으로 난 뭘 해 먹고 살까?\n접기       222.0         화
# 4    환생한 현대의 카페 주인, 한 잔의 차와 다과로 온 중원을 사로잡다.\n\n평범하게...       286.0         화
# 5    일제강점기로 회귀했다.\n\n이왕이면 크게 놀아보자.\n전쟁, 자원과 영토를 두고 ...       281.0         화
# ..                                                 ...         ...       ...
# 120  한국대학교 농생대 3학년 김종손.\n\n호시탐탐 나를 조교로 부릴 기회만 엿보던 교...        64.0         화
# 121  세상을 떠난 망돌 절친에게서 마지막 편지가 도착했다.\n\n편지를 읽는 순간,\n눈...       119.0         화
# 122            서유기는 아직 끝나지 않았다. \n두 번째 서유기는 무림에서 시작되었다        57.0         화
# 123  약하면 지킬 수 없단 걸 깨달았다.\n\n3월 21일 소중한 이가 겨울이 끝남과 동...        50.0         화
# 124  권력은 남았고 시대만 바뀌었다!\n\n힘과 의리.배신과 모략이  뒤엉킨\n도시의 전...        36.0         화
#
#          age status error crawled_at
# 0    15세 이용가    NaN   NaN        NaN
# 2     전체 이용가    NaN   NaN        NaN
# 3     전체 이용가    NaN   NaN        NaN
# 4     전체 이용가    NaN   NaN        NaN
# 5     전체 이용가    NaN   NaN        NaN
# ..       ...    ...   ...        ...
# 120   전체 이용가    NaN   NaN        NaN
# 121   전체 이용가    NaN   NaN        NaN
# 122   전체 이용가    NaN   NaN        NaN
# 123   전체 이용가    NaN   NaN        NaN
# 124   전체 이용가    NaN   NaN        NaN
#
# [115 rows x 14 columns]

# %%
import pickle

with open('data/naver_novel_page_link_data.data', 'rb') as f:
    a = pickle.load(f)

# 데이터 나누기
def split_data(data, split_num):
    """리스트와 딕셔너리 모두 처리하는 범용 분할 함수"""
    
    if isinstance(data, list):
        # 리스트인 경우 (기존 로직)
        new_data = []
        for i in range(0, len(data), split_num):
            new_data.append(data[i: i+split_num])
        return new_data
    
    elif isinstance(data, dict):
        # 딕셔너리인 경우
        items = list(data.items())  # (key, value) 튜플들의 리스트
        new_data = []
        
        for i in range(0, len(items), split_num):
            batch_items = items[i: i+split_num]
            batch_dict = dict(batch_items)  # 다시 딕셔너리로 변환
            new_data.append(batch_dict)
        
        return new_data
    
    else:
        raise TypeError(f"지원하지 않는 타입입니다: {type(data)}")

# urls = split_data(a, 5)
a[0][0]
# Out:
# {'age': '전체',
#  'url': 'https://series.naver.com/novel/categoryProductList.series?categoryTypeCode=all&page=1'}

# %%
import pickle
import json
import pandas as pd


df = pd.read_csv('data/naver_novel_data.csv', encoding='utf-8')
print(df.shape)
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 6
#       2 import json
#       3 import pandas as pd
# ----> 6 df = pd.read_csv('data/naver_novel_data.csv', encoding='utf-8')
#       7 print(df.shape)
#       8 df.head()
#
# File ~/python/recommend_site/.venv/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/python/recommend_site/.venv/lib/python3.11/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~/python/recommend_site/.venv/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~/python/recommend_site/.venv/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~/python/recommend_site/.venv/lib/python3.11/site-packages/pandas/io/common.py:882, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#    (...)    878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
# --> 882         handle = open(handle, ioargs.mode)
#     883     handles.append(handle)
#     885 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/naver_novel_data.csv'

# %%
import json
import pickle
from itertools import chain

with open('data/novelpia_novel_page_link_data.data', 'rb') as f:
    a = pickle.load(f)

# all_urls = list(chain.from_iterable(a))
a
# Out:
# ['https://novelpia.com/novel/351974',
#  'https://novelpia.com/novel/347065',
#  'https://novelpia.com/novel/354038',
#  'https://novelpia.com/novel/308223',
#  'https://novelpia.com/novel/294863',
#  'https://novelpia.com/novel/342156',
#  'https://novelpia.com/novel/307138',
#  'https://novelpia.com/novel/156655',
#  'https://novelpia.com/novel/330800',
#  'https://novelpia.com/novel/96091',
#  'https://novelpia.com/novel/356832',
#  'https://novelpia.com/novel/358218',
#  'https://novelpia.com/novel/357611',
#  'https://novelpia.com/novel/347341',
#  'https://novelpia.com/novel/341804',
#  'https://novelpia.com/novel/330389',
#  'https://novelpia.com/novel/325323',
#  'https://novelpia.com/novel/291706',
#  'https://novelpia.com/novel/282632',
#  'https://novelpia.com/novel/289966',
#  'https://novelpia.com/novel/315836',
#  'https://novelpia.com/novel/294376',
#  'https://novelpia.com/novel/361179',
#  'https://novelpia.com/novel/346289',
#  'https://novelpia.com/novel/294363',
#  'https://novelpia.com/novel/358245',
#  'https://novelpia.com/novel/332955',
#  'https://novelpia.com/novel/358785',
#  'https://novelpia.com/novel/357565',
#  'https://novelpia.com/novel/347096',
#  'https://novelpia.com/novel/355448',
#  'https://novelpia.com/novel/347987',
#  'https://novelpia.com/novel/316047',
#  'https://novelpia.com/novel/332333',
#  'https://novelpia.com/novel/347617',
#  'https://novelpia.com/novel/332744',
#  'https://novelpia.com/novel/265463',
#  'https://novelpia.com/novel/338332',
#  'https://novelpia.com/novel/285308',
#  'https://novelpia.com/novel/312018',
#  'https://novelpia.com/novel/96219',
#  'https://novelpia.com/novel/233825',
#  'https://novelpia.com/novel/307182',
#  'https://novelpia.com/novel/233169',
#  'https://novelpia.com/novel/331122',
#  'https://novelpia.com/novel/307751',
#  'https://novelpia.com/novel/350979',
#  'https://novelpia.com/novel/273326',
#  'https://novelpia.com/novel/331063',
#  'https://novelpia.com/novel/141576',
#  'https://novelpia.com/novel/308921',
#  'https://novelpia.com/novel/350529',
#  'https://novelpia.com/novel/351270',
#  'https://novelpia.com/novel/28295',
#  'https://novelpia.com/novel/341641',
#  'https://novelpia.com/novel/349642',
#  'https://novelpia.com/novel/264692',
#  'https://novelpia.com/novel/213830',
#  'https://novelpia.com/novel/335878',
#  'https://novelpia.com/novel/247387',
#  'https://novelpia.com/novel/336982',
#  'https://novelpia.com/novel/347420',
#  'https://novelpia.com/novel/336435',
#  'https://novelpia.com/novel/250230',
#  'https://novelpia.com/novel/347592',
#  'https://novelpia.com/novel/346998',
#  'https://novelpia.com/novel/330310',
#  'https://novelpia.com/novel/346831',
#  'https://novelpia.com/novel/233390',
#  'https://novelpia.com/novel/224265',
#  'https://novelpia.com/novel/347985',
#  'https://novelpia.com/novel/343054',
#  'https://novelpia.com/novel/339246',
#  'https://novelpia.com/novel/106675',
#  'https://novelpia.com/novel/347010',
#  'https://novelpia.com/novel/350210',
#  'https://novelpia.com/novel/291152',
#  'https://novelpia.com/novel/160129',
#  'https://novelpia.com/novel/307282',
#  'https://novelpia.com/novel/200147',
#  'https://novelpia.com/novel/347026',
#  'https://novelpia.com/novel/339207',
#  'https://novelpia.com/novel/346873',
#  'https://novelpia.com/novel/307256',
#  'https://novelpia.com/novel/291013',
#  'https://novelpia.com/novel/243029',
#  'https://novelpia.com/novel/347645',
#  'https://novelpia.com/novel/283973',
#  'https://novelpia.com/novel/330850',
#  'https://novelpia.com/novel/321857',
#  'https://novelpia.com/novel/224763',
#  'https://novelpia.com/novel/310400',
#  'https://novelpia.com/novel/330702',
#  'https://novelpia.com/novel/330414',
#  'https://novelpia.com/novel/131938',
#  'https://novelpia.com/novel/26536',
#  'https://novelpia.com/novel/334232',
#  'https://novelpia.com/novel/348306',
#  'https://novelpia.com/novel/337949',
#  'https://novelpia.com/novel/283166',
#  'https://novelpia.com/novel/337065',
#  'https://novelpia.com/novel/293319',
#  'https://novelpia.com/novel/145866',
#  'https://novelpia.com/novel/347053',
#  'https://novelpia.com/novel/280312',
#  'https://novelpia.com/novel/349923',
#  'https://novelpia.com/novel/307755',
#  'https://novelpia.com/novel/351942',
#  'https://novelpia.com/novel/350501',
#  'https://novelpia.com/novel/340915',
#  'https://novelpia.com/novel/285471',
#  'https://novelpia.com/novel/350309',
#  'https://novelpia.com/novel/352992',
#  'https://novelpia.com/novel/332530',
#  'https://novelpia.com/novel/237906',
#  'https://novelpia.com/novel/349510',
#  'https://novelpia.com/novel/332910',
#  'https://novelpia.com/novel/90485',
#  'https://novelpia.com/novel/310140',
#  'https://novelpia.com/novel/331437',
#  'https://novelpia.com/novel/256856',
#  'https://novelpia.com/novel/341707',
#  'https://novelpia.com/novel/284686',
#  'https://novelpia.com/novel/348077',
#  'https://novelpia.com/novel/347173',
#  'https://novelpia.com/novel/323647',
#  'https://novelpia.com/novel/338280',
#  'https://novelpia.com/novel/239336',
#  'https://novelpia.com/novel/146934',
#  'https://novelpia.com/novel/282657',
#  'https://novelpia.com/novel/320757',
#  'https://novelpia.com/novel/255103',
#  'https://novelpia.com/novel/32343',
#  'https://novelpia.com/novel/350887',
#  'https://novelpia.com/novel/217546',
#  'https://novelpia.com/novel/350137',
#  'https://novelpia.com/novel/358760',
#  'https://novelpia.com/novel/282944',
#  'https://novelpia.com/novel/288918',
#  'https://novelpia.com/novel/233173',
#  'https://novelpia.com/novel/352179',
#  'https://novelpia.com/novel/322218',
#  'https://novelpia.com/novel/233265',
#  'https://novelpia.com/novel/51457',
#  'https://novelpia.com/novel/349274',
#  'https://novelpia.com/novel/332154',
#  'https://novelpia.com/novel/270609',
#  'https://novelpia.com/novel/351851',
#  'https://novelpia.com/novel/346933',
#  'https://novelpia.com/novel/253245',
#  'https://novelpia.com/novel/324238',
#  'https://novelpia.com/novel/232768',
#  'https://novelpia.com/novel/348638',
#  'https://novelpia.com/novel/307617',
#  'https://novelpia.com/novel/308293',
#  'https://novelpia.com/novel/329464',
#  'https://novelpia.com/novel/25974',
#  'https://novelpia.com/novel/232905',
#  'https://novelpia.com/novel/349978',
#  'https://novelpia.com/novel/211403',
#  'https://novelpia.com/novel/358549',
#  'https://novelpia.com/novel/356386',
#  'https://novelpia.com/novel/348163',
#  'https://novelpia.com/novel/348073',
#  'https://novelpia.com/novel/292772',
#  'https://novelpia.com/novel/96806',
#  'https://novelpia.com/novel/351056',
#  'https://novelpia.com/novel/346695',
#  'https://novelpia.com/novel/216719',
#  'https://novelpia.com/novel/293470',
#  'https://novelpia.com/novel/208565',
#  'https://novelpia.com/novel/353885',
#  'https://novelpia.com/novel/310260',
#  'https://novelpia.com/novel/348068',
#  'https://novelpia.com/novel/211581',
#  'https://novelpia.com/novel/307428',
#  'https://novelpia.com/novel/270682',
#  'https://novelpia.com/novel/330898',
#  'https://novelpia.com/novel/177953',
#  'https://novelpia.com/novel/347376',
#  'https://novelpia.com/novel/334767',
#  'https://novelpia.com/novel/347459',
#  'https://novelpia.com/novel/344445',
#  'https://novelpia.com/novel/356084',
#  'https://novelpia.com/novel/355474',
#  'https://novelpia.com/novel/225019',
#  'https://novelpia.com/novel/49942',
#  'https://novelpia.com/novel/293214',
#  'https://novelpia.com/novel/71273',
#  'https://novelpia.com/novel/331631',
#  'https://novelpia.com/novel/345977',
#  'https://novelpia.com/novel/8028',
#  'https://novelpia.com/novel/250485',
#  'https://novelpia.com/novel/348032',
#  'https://novelpia.com/novel/126048',
#  'https://novelpia.com/novel/202874',
#  'https://novelpia.com/novel/328563',
#  'https://novelpia.com/novel/178019',
#  'https://novelpia.com/novel/178346',
#  'https://novelpia.com/novel/50225',
#  'https://novelpia.com/novel/50356',
#  'https://novelpia.com/novel/250436',
#  'https://novelpia.com/novel/255599',
#  'https://novelpia.com/novel/251756',
#  'https://novelpia.com/novel/357877',
#  'https://novelpia.com/novel/254709',
#  'https://novelpia.com/novel/347184',
#  'https://novelpia.com/novel/346977',
#  'https://novelpia.com/novel/307042',
#  'https://novelpia.com/novel/331240',
#  'https://novelpia.com/novel/347063',
#  'https://novelpia.com/novel/174313',
#  'https://novelpia.com/novel/78712',
#  'https://novelpia.com/novel/234583',
#  'https://novelpia.com/novel/251036',
#  'https://novelpia.com/novel/354358',
#  'https://novelpia.com/novel/7737',
#  'https://novelpia.com/novel/330363',
#  'https://novelpia.com/novel/41477',
#  'https://novelpia.com/novel/128571',
#  'https://novelpia.com/novel/319159',
#  'https://novelpia.com/novel/347288',
#  'https://novelpia.com/novel/349275',
#  'https://novelpia.com/novel/337551',
#  'https://novelpia.com/novel/322506',
#  'https://novelpia.com/novel/243470',
#  'https://novelpia.com/novel/354603',
#  'https://novelpia.com/novel/314965',
#  'https://novelpia.com/novel/285503',
#  'https://novelpia.com/novel/351757',
#  'https://novelpia.com/novel/141611',
#  'https://novelpia.com/novel/347707',
#  'https://novelpia.com/novel/347438',
#  'https://novelpia.com/novel/322611',
#  'https://novelpia.com/novel/331224',
#  'https://novelpia.com/novel/167503',
#  'https://novelpia.com/novel/221259',
#  'https://novelpia.com/novel/170522',
#  'https://novelpia.com/novel/17906',
#  'https://novelpia.com/novel/307565',
#  'https://novelpia.com/novel/237876',
#  'https://novelpia.com/novel/195925',
#  'https://novelpia.com/novel/201103',
#  'https://novelpia.com/novel/102155',
#  'https://novelpia.com/novel/346737',
#  'https://novelpia.com/novel/35429',
#  'https://novelpia.com/novel/265760',
#  'https://novelpia.com/novel/275862',
#  'https://novelpia.com/novel/295218',
#  'https://novelpia.com/novel/336503',
#  'https://novelpia.com/novel/320555',
#  'https://novelpia.com/novel/96682',
#  'https://novelpia.com/novel/81574',
#  'https://novelpia.com/novel/232985',
#  'https://novelpia.com/novel/348422',
#  'https://novelpia.com/novel/28408',
#  'https://novelpia.com/novel/298596',
#  'https://novelpia.com/novel/347076',
#  'https://novelpia.com/novel/324602',
#  'https://novelpia.com/novel/294885',
#  'https://novelpia.com/novel/233251',
#  'https://novelpia.com/novel/349363',
#  'https://novelpia.com/novel/344230',
#  'https://novelpia.com/novel/350220',
#  'https://novelpia.com/novel/350831',
#  'https://novelpia.com/novel/319634',
#  'https://novelpia.com/novel/141671',
#  'https://novelpia.com/novel/233559',
#  'https://novelpia.com/novel/291028',
#  'https://novelpia.com/novel/282599',
#  'https://novelpia.com/novel/348464',
#  'https://novelpia.com/novel/307619',
#  'https://novelpia.com/novel/353157',
#  'https://novelpia.com/novel/349243',
#  'https://novelpia.com/novel/300047',
#  'https://novelpia.com/novel/336059',
#  'https://novelpia.com/novel/337635',
#  'https://novelpia.com/novel/348148',
#  'https://novelpia.com/novel/286250',
#  'https://novelpia.com/novel/57924',
#  'https://novelpia.com/novel/348379',
#  'https://novelpia.com/novel/343083',
#  'https://novelpia.com/novel/308640',
#  'https://novelpia.com/novel/164581',
#  'https://novelpia.com/novel/232694',
#  'https://novelpia.com/novel/350931',
#  'https://novelpia.com/novel/350592',
#  'https://novelpia.com/novel/346691',
#  'https://novelpia.com/novel/347787',
#  'https://novelpia.com/novel/141330',
#  'https://novelpia.com/novel/322441',
#  'https://novelpia.com/novel/330741',
#  'https://novelpia.com/novel/342853',
#  'https://novelpia.com/novel/211733',
#  'https://novelpia.com/novel/278694',
#  'https://novelpia.com/novel/330370',
#  'https://novelpia.com/novel/342411',
#  'https://novelpia.com/novel/255498',
#  'https://novelpia.com/novel/350541',
#  'https://novelpia.com/novel/282758',
#  'https://novelpia.com/novel/286013',
#  'https://novelpia.com/novel/307351',
#  'https://novelpia.com/novel/283322',
#  'https://novelpia.com/novel/218054',
#  'https://novelpia.com/novel/194609',
#  'https://novelpia.com/novel/127100',
#  'https://novelpia.com/novel/266035',
#  'https://novelpia.com/novel/128022',
#  'https://novelpia.com/novel/282498',
#  'https://novelpia.com/novel/348005',
#  'https://novelpia.com/novel/223724',
#  'https://novelpia.com/novel/120683',
#  'https://novelpia.com/novel/27717',
#  'https://novelpia.com/novel/293120',
#  'https://novelpia.com/novel/212348',
#  'https://novelpia.com/novel/235361',
#  'https://novelpia.com/novel/205941',
#  'https://novelpia.com/novel/239090',
#  'https://novelpia.com/novel/257317',
#  'https://novelpia.com/novel/351157',
#  'https://novelpia.com/novel/317754',
#  'https://novelpia.com/novel/298806',
#  'https://novelpia.com/novel/301122',
#  'https://novelpia.com/novel/2738',
#  'https://novelpia.com/novel/335176',
#  'https://novelpia.com/novel/250876',
#  'https://novelpia.com/novel/326735',
#  'https://novelpia.com/novel/200845',
#  'https://novelpia.com/novel/344267',
#  'https://novelpia.com/novel/215298',
#  'https://novelpia.com/novel/141298',
#  'https://novelpia.com/novel/347792',
#  'https://novelpia.com/novel/346881',
#  'https://novelpia.com/novel/72076',
#  'https://novelpia.com/novel/273263',
#  'https://novelpia.com/novel/97495',
#  'https://novelpia.com/novel/357955',
#  'https://novelpia.com/novel/215602',
#  'https://novelpia.com/novel/349143',
#  'https://novelpia.com/novel/355487',
#  'https://novelpia.com/novel/326948',
#  'https://novelpia.com/novel/153076',
#  'https://novelpia.com/novel/282340',
#  'https://novelpia.com/novel/347972',
#  'https://novelpia.com/novel/152704',
#  'https://novelpia.com/novel/309529',
#  'https://novelpia.com/novel/24226',
#  'https://novelpia.com/novel/289206',
#  'https://novelpia.com/novel/153829',
#  'https://novelpia.com/novel/327011',
#  'https://novelpia.com/novel/172751',
#  'https://novelpia.com/novel/285198',
#  'https://novelpia.com/novel/206196',
#  'https://novelpia.com/novel/351034',
#  'https://novelpia.com/novel/264209',
#  'https://novelpia.com/novel/347234',
#  'https://novelpia.com/novel/269421',
#  'https://novelpia.com/novel/347613',
#  'https://novelpia.com/novel/351207',
#  ...]
